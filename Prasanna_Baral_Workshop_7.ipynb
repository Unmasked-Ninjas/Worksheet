# %% [markdown]
# <a href="https://colab.research.google.com/github/Unmasked-Ninjas/Worksheet/blob/main/Prasanna_Baral_Workshop_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/Dataset/diabetes.csv");
#feature matrix
X = data.drop(columns = ["BloodPressure"]);
#target vector
y = data["BloodPressure"];
X
# Out:
#      Pregnancies  Glucose  SkinThickness  Insulin   BMI  \
# 0              6      148             35        0  33.6
# 1              1       85             29        0  26.6
# 2              8      183              0        0  23.3
# 3              1       89             23       94  28.1
# 4              0      137             35      168  43.1
# ..           ...      ...            ...      ...   ...
# 763           10      101             48      180  32.9
# 764            2      122             27        0  36.8
# 765            5      121             23      112  26.2
# 766            1      126              0        0  30.1
# 767            1       93             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state =0 );

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
c
# Out:
# 30.018847299942195

# %%
m = lr.coef_
m
# Out:
# array([ 0.20835986,  0.05091433,  0.2330124 , -0.00554345,  0.51452546,
#        -0.2230586 ,  0.39281781, -4.91472901])

# %%
y_pred_test = lr.predict(X_test)
y_pred_test
# Out:
# array([75.86815323, 68.55217622, 61.94887065, 71.23235706, 60.35779752,
#        61.3746319 , 72.05339311, 77.41949   , 64.68544131, 83.84664116,
#        67.8720424 , 83.83274826, 71.90122347, 63.20476186, 73.1837702 ,
#        66.61901064, 75.75657839, 56.30201819, 83.85713576, 71.33249933,
#        74.94553256, 61.69646545, 64.74220555, 75.98913985, 58.35535246,
#        70.55151411, 55.2574667 , 84.31055046, 63.48652959, 61.75828587,
#        76.97872242, 74.52656047, 64.11790809, 75.23348713, 59.89381898,
#        67.70282972, 72.75663369, 61.57159213, 74.91200017, 72.89245415,
#        66.59190858, 65.32093784, 66.73745871, 70.50267446, 79.50355051,
#        48.69297854, 64.26694202, 62.95052968, 69.10784426, 59.40754263,
#        66.85303078, 66.93653597, 79.37945174, 79.70363111, 71.20934847,
#        56.20699756, 67.09772044, 70.17174163, 56.12705574, 44.76918066,
#        80.91224105, 72.19336638, 57.29514121, 60.41990145, 62.00339354,
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_pred_test)
mse = mean_squared_error(y_test, y_pred_test)
rmse = mean_squared_error(y_test, y_pred_test)
r2 = r2_score(y_test, y_pred_test)
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# MAE: 11.55107388934605
# MSE: 283.9941697590914
# RMSE: 283.9941697590914
# R2 Score: 0.17478067969939026

# %%
from sklearn.linear_model import LogisticRegression

# %%
X = data.drop(columns = ["Outcome"]);
y = data["Outcome"];

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state =22)
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 738            2       99             60             17      160  36.6
# 178            5      143             78              0        0  45.0
# 185            7      194             68             28        0  35.9
# 647            0      179             50             36      159  37.8
# 654            1      106             70             28      135  34.2
# ..           ...      ...            ...            ...      ...   ...
# 491            2       89             90             30        0  33.5
# 502            6        0             68             41        0  39.0
# 358           12       88             74             40       54  35.3
# 356            1      125             50             40      167  33.3
# 132            3      170             64             37      225  34.5
#
#      DiabetesPedigreeFunction  Age
# 738                     0.453   21
# 178                     0.190   47
# ...

# %%
lr = LogisticRegression(max_iter=10000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
lr.score(X_train, y_train)
# Out:
# 0.7915309446254072

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[92  8]
#  [30 24]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83       100
#            1       0.75      0.44      0.56        54
#
#     accuracy                           0.75       154
#    macro avg       0.75      0.68      0.69       154
# weighted avg       0.75      0.75      0.73       154
